# %%
import pandas as pd
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rc("font", size=18)
plt.rcParams["figure.figsize"] = (20, 10)

# %%
data = pd.read_csv("data.csv")
data.head(4)
# Out:
#    Linear   Laplace1   Laplace2
# 0       8   6.476565   2.600832
# 1      16   9.887645   5.200000
# 2      32  14.247544  10.250312

# %%
x = [8, 16, 32]
x_names = ["8\n1/8", "16\n2/8", "32\n4/8"]

# %%
plt.plot(x, data["Linear"], c='purple', marker='x')
plt.plot(x, data["Laplace1"], c='blue', marker='.')
plt.plot(x, data["Laplace2"], c='red', marker='P')
plt.grid()
plt.title("Parallel solution of the stationary two-dimensional Laplace's equation")
plt.legend(["Linear speedup", "Laplace's equation (n = 1000)", "Laplace's equation (n = 10000)"])
plt.yticks(x)
plt.xticks(x, x_names)
plt.ylabel("Speedup")
plt.xlabel("Number of processes")
plt.show()
