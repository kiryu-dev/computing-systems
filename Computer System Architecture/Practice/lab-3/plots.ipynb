# %%
import pandas as pd
import numpy as np

# %%
import matplotlib
import matplotlib.pyplot as plt

matplotlib.rc("font", size=18)

# %%
data = pd.read_csv("data.csv")
data.head(15)
# Out:
#    MemoryType  BlockSize ElementType  BufferSize  LaunchNum         Timer  \
# 0         RAM     131072         int           1          1  gettimeofday
# 1         RAM     131072         int           1          2  gettimeofday
# 2         RAM     131072         int           1          3  gettimeofday
# 3         RAM     131072         int           1          4  gettimeofday
# 4         RAM     131072         int           1          5  gettimeofday
# 5         RAM     131072         int           1          6  gettimeofday
# 6         RAM     131072         int           1          7  gettimeofday
# 7         RAM     131072         int           1          8  gettimeofday
# 8         RAM     131072         int           1          9  gettimeofday
# 9         RAM     131072         int           1         10  gettimeofday
# 10        RAM     131072      double           1          1  gettimeofday
# 11        RAM     131072      double           1          2  gettimeofday
# 12        RAM     131072      double           1          3  gettimeofday
# 13        RAM     131072      double           1          4  gettimeofday
# 14        RAM     131072      double           1          5  gettimeofday
#
#     WriteTime  AverageWriteTime  WriteBandwidth  AbsError(write)  \
# 0    0.000968          0.000912    1.437800e+14         0.000057
# 1    0.000968          0.000912    1.437800e+14         0.000057
# 2    0.000880          0.000912    1.437800e+14         0.000032
# 3    0.000903          0.000912    1.437800e+14         0.000009
# 4    0.000926          0.000912    1.437800e+14         0.000015
# 5    0.000895          0.000912    1.437800e+14         0.000016
# 6    0.000890          0.000912    1.437800e+14         0.000022
# 7    0.000899          0.000912    1.437800e+14         0.000013
# 8    0.000904          0.000912    1.437800e+14         0.000008
# 9    0.000883          0.000912    1.437800e+14         0.000029
# 10   0.000495          0.000483    2.714980e+14         0.000012
# 11   0.000522          0.000483    2.714980e+14         0.000039
# 12   0.000454          0.000483    2.714980e+14         0.000028
# 13   0.000587          0.000483    2.714980e+14         0.000104
# 14   0.000437          0.000483    2.714980e+14         0.000046
#
#     RelError(write)  ReadTime  AverageReadTime  ReadBandwidth  AbsError(read)  \
# 0          5.869030  0.000848         0.000904   1.450390e+14        0.000056
# 1          5.869030  0.001004         0.000904   1.450390e+14        0.000100
# 2          3.648690  0.000848         0.000904   1.450390e+14        0.000056
# 3          0.966464  0.000897         0.000904   1.450390e+14        0.000006
# 4          1.580440  0.000848         0.000904   1.450390e+14        0.000055
# 5          1.826900  0.000898         0.000904   1.450390e+14        0.000005
# 6          2.481910  0.000993         0.000904   1.450390e+14        0.000089
# 7          1.394860  0.000937         0.000904   1.450390e+14        0.000034
# 8          0.859931  0.000894         0.000904   1.450390e+14        0.000010
# 9          3.256820  0.000870         0.000904   1.450390e+14        0.000034
# 10         2.461460  0.000460         0.000476   2.755940e+14        0.000016
# 11         7.454300  0.000504         0.000476   2.755940e+14        0.000028
# 12         6.238200  0.000647         0.000476   2.755940e+14        0.000171
# 13        17.687000  0.000450         0.000476   2.755940e+14        0.000026
# 14        10.529500  0.000422         0.000476   2.755940e+14        0.000053
#
#     RelError(read)
# 0         6.561710
# 1         9.966750
# 2         6.621660
# 3         0.701382
# 4         6.531760
# 5         0.594480
# 6         8.950280
# 7         3.576700
# 8         1.104290
# 9         3.875030
# 10        3.464730
# 11        5.549240
# 12       26.445400
# 13        5.712770
# 14       12.573400

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(18)

plt.plot(data["BlockSize"][80:100], data["WriteBandwidth"][80:100], c='purple')
plt.plot(data["BlockSize"][80:100], data["ReadBandwidth"][80:100], c='red')
plt.plot(data["BlockSize"][100:], data["WriteBandwidth"][100:], c='blue')
plt.plot(data["BlockSize"][100:], data["ReadBandwidth"][100:], c='green')
plt.grid()
plt.title('Зависимость пропускной способности записи и чтения от размера блока данных (BlockSize) для разного типа памяти')
plt.legend(['int write', 'int read', 'double write', 'double read'])
plt.show()

# %%
underplot_names = [f"{4 * i + 4} Mb" for i in range(20)]

plt.figure().set_figheight(10)
plt.figure().set_figwidth(18)

x = np.arange(len(underplot_names))
width = 0.3

fig, ax = plt.subplots()

rects1 = ax.bar(x - width/2, data["WriteBandwidth"][80:100], width, label='write bandwidth')
rects2 = ax.bar(x + width/2, data["ReadBandwidth"][80:100], width, label='read bandwidth')
ax.set_title('int SSD')
ax.set_xticks(x)
ax.set_xticklabels(underplot_names)
ax.legend()

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(18)

plt.plot(data["BlockSize"][80:100], data["AbsError(write)"][80:100], c='purple')
plt.plot(data["BlockSize"][80:100], data["AbsError(read)"][80:100], c='red')
plt.plot(data["BlockSize"][100:], data["AbsError(write)"][100:], c='blue')
plt.plot(data["BlockSize"][100:], data["AbsError(read)"][100:], c='green')
plt.grid()
plt.title('Зависимость погрешности измерения пропускной способности от размера блока данных для разного типа памяти')
plt.legend(['int write', 'int read', 'double write', 'double read'])
plt.show()

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(18)

plt.plot(data["BlockSize"][80:100], data["RelError(write)"][80:100], c='purple')
plt.plot(data["BlockSize"][80:100], data["RelError(read)"][80:100], c='red')
plt.plot(data["BlockSize"][100:], data["RelError(write)"][100:], c='blue')
plt.plot(data["BlockSize"][100:], data["RelError(read)"][100:], c='green')
plt.grid()
plt.title('Зависимость погрешности измерения пропускной способности от размера блока данных для разного типа памяти')
plt.legend(['int write', 'int read', 'double write', 'double read'])
plt.show()

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(18)

plt.plot(data["LaunchNum"][80:100], data["AbsError(write)"][80:100], c='purple')
plt.plot(data["LaunchNum"][80:100], data["AbsError(read)"][80:100], c='red')
plt.plot(data["LaunchNum"][100:], data["AbsError(write)"][100:], c='blue')
plt.plot(data["LaunchNum"][100:], data["AbsError(read)"][100:], c='green')
plt.grid()
plt.title('Зависимость погрешности измерений от числа испытаний LaunchNum')
plt.legend(['int write', 'int read', 'double write', 'double read'])
plt.show()

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(18)

plt.plot(data["LaunchNum"][80:100], data["RelError(write)"][80:100], c='purple')
plt.plot(data["LaunchNum"][80:100], data["RelError(read)"][80:100], c='red')
plt.plot(data["LaunchNum"][100:], data["RelError(write)"][100:], c='blue')
plt.plot(data["LaunchNum"][100:], data["RelError(read)"][100:], c='green')
plt.grid()
plt.title('Зависимость погрешности измерений от числа испытаний LaunchNum')
plt.legend(['int write', 'int read', 'double write', 'double read'])
plt.show()

# %%
plt.figure().set_figheight(10)
plt.figure().set_figwidth(18)

plt.plot(data["LaunchNum"][:10], data["AbsError(write)"][:10], c='purple')
plt.plot(data["LaunchNum"][:10], data["AbsError(read)"][:10], c='red')
plt.plot(data["LaunchNum"][10:20], data["AbsError(write)"][10:20], c='blue')
plt.plot(data["LaunchNum"][10:20], data["AbsError(read)"][10:20], c='green')
plt.grid()
plt.title('Зависимость погрешности измерений от числа испытаний LaunchNum')
plt.legend(['int write', 'int read', 'double write', 'double read'])
plt.show()
